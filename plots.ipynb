# %%
# %matplotlib inline
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np

r1 = np.load('r1.npy')
r2 = np.load('r2.npy')

# %%
plt.figure(figsize=(12,12))
plt.imshow(r1.T, extent=[-2, 1, -1.5, 1.5])

plt.figure(figsize=(12,12))
plt.imshow(r2.T, extent=[-2, 1, -1.5, 1.5])
